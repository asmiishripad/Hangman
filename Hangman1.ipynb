# %%
import random
continue_game = True
while continue_game:
    print("____________________________________________________________________________________")
    print()
    continue_game = True
    countries = ["Argentina", "Australia", "Bulgaria", "Cambodia", "Cameroon", "Colombia", "Dominica", "Ethiopia", "Finland", "Zimbabwe", "Malaysia", "Mongolia", "Pakistan", "Portugal", "Slovakia", "Slovenia", "Thailand", "Botswana", "Cameroon", "Colombia", "Dominica", "Ethiopia", "Kiribati", "Malaysia", "Mongolia", "Pakistan", "Paraguay", "Portugal", "Slovenia", "Suriname", "Tanzania", "Thailand", "Venezuela", "Guatemala", "Indonesia", "Mauritius", "Nicaragua", "Singapore", "Sri Lanka", "Australia", "Azerbaijan", "Bangladesh", "Burundi", "Venezuela", "Lithuania", "Macedonia", "Malaysia", "Mongolia", "Portugal", "Suriname"]
    colours = ["Aquamarine", "Bittersweet", "Chartreuse", "Darkviolet", "Firebrick", "Gold", "Honeydew", "Indianred", "Lavender", "Lavenderblush", "Lightcoral", "Lightseagreen", "Mediumvioletred", "Navajowhite", "Orangered", "Palegoldenrod", "Palegreen", "Papayawhip", "Peachpuff", "Powderblue", "Rosybrown", "Saddlebrown", "Sandybrown", "Seagreen", "Skyblue", "Slateblue", "Springgreen", "Steelblue", "Tan", "Thistle", "Turquoise", "Violet", "Wheat", "Yellowgreen", "Antiquewhite", "Blueviolet", "Burlywood", "Cadetblue", "Chocolate", "Cornflowerblue", "Crimson", "Darkorange", "Darkseagreen", "Darkslateblue", "Deepskyblue", "Floralwhite", "Forestgreen", "Gainsboro", "Ghostwhite", "Goldenrod", "Greenyellow"]
    fruits = ["pineapple", "strawberry", "blackberry", "watermelon", "cantaloupe", "raspberry", "grapefruit", "blueberry", "pomegranate", "nectarine", "tangerine", "persimmon", "papaya", "cranberry", "grape", "kiwifruit", "guava", "passionfruit", "dragonfruit", "clementine", "boysenberry", "blackcurrant", "apricot", "mulberry", "kumquat", "mango", "lingonberry", "soursop", "starfruit", "plantain", "feijoa", "gooseberry", "jackfruit", "pummelo", "quince", "tamarillo", "uglifruit", "yuzu", "ackee", "bilberry", "cherimoya", "durian", "elderberry", "grapple", "honeydew", "jujube", "apple"]
    print("Welcome to Asmii's Hangman !")
    print()
    print("The easy mode gives you 6 chances to guess a word right whereas the hard mode gives you only 3 chancs to guess the word. Good Luck !!")

    try: 
        level = input("Choose a game mode !(easy/hard)")
        if (level.strip().lower() != "easy") and (level.strip().lower() != "hard"):
            print("Please choose a valid game mode (easy/hard)")
        else:
            if level == "easy":
                category_check = False
                lives_left = 6
                lives_used = 0

                while category_check == False: 
                    try: 
                        category = input("Choose a category (countries/colours/fruits): ")
                        if (((category.strip()).lower() != "countries") and ((category.strip()).lower() != "colors") and ((category.strip()).lower() != "colours") and ((category.strip()).lower() != "fruits")):
                            print("Please choose a category(countries/colours/fruits)")
                        elif category.strip() == "":
                            print("Please choose a category(countries/colours/fruits)")
                        else:
                            category_check = True
                            
                    except ValueError:
                        print("Invalid data type. Please enter a string for the category")
    
                rand_no = random.randint(0,24)
                word = ""
    
                if category.lower() == "countries":
                    word = countries[rand_no].lower()
                elif (category.lower()== "colors") or (category.lower() == "colours"):
                    word = colours[rand_no].lower()
                elif category.lower() == "fruits":
                    word = fruits[rand_no].lower()
            
                guesses = []
                for i in word:
                    if (i in "aeiou") and (i not in guesses):
                        guesses.append(i)
    
                dummy_word = []
                for i in range(0, len(word)):
                    dummy_word.append("")
                    
                for i in range(0, len(word)):
                    if word[i] in "aeiou":
                        dummy_word[i] = word[i]
                    elif word[i] == " ":
                        break
                    else:
                       dummy_word[i] = " _ "
                
                for p in range(0, len(word)): 
                    print(dummy_word[p], end = "")
                
                print()
                
                chances = 0
     
                while chances < 6:
                    answer_check = False
                    while answer_check == False:
                        try: 
                            answer = input("Guess a letter !")
                            print()
                            if len(answer.strip()) > 1:
                                print("Please enter a single letter ")
                                print()
                            elif len(answer.strip()) == 1:
                                guess_check = False
                                for guess in guesses: 
                                    if guess == answer:
                                        guess_check = True
                                        break
                                if guess_check == True: 
                                    print("This letter is already there and/or guessed, Please try another letter !")
                            
                                else:
                                    correct_guess = False
                                    answer_check = True
                                    guesses.append(answer)
                                    if answer in word:
                                        for i in range(0, len(word)):
                                            if answer == word[i]:
                                                dummy_word[i] = word[i]
                                                correct_guess = True
                                    
                                        if correct_guess == True: 
                                            print("It is a correct guess !!")
                    
                                        for p in range(0, len(word)):
                                            print(dummy_word[p], end = "")
                          
                                    else: 
                                        print("Sorry ! It is a wrong guess. Try again")
                                    
                                        chances += 1
                                    
                                        for p in range(0, len(word)):
                                            print(dummy_word[p], end = "")
                                        
                                    if chances == 1 and correct_guess == False:
                                        print('''
                                              +---+
                                              |   |
                                              O   |
                                                  |
                                                  |
                                                  |
                                            =========''')
                                        lives_left -= 1
                                        lives_used += 1
                                        print()
                                        print("You are now left with ", lives_left, "chances")
                                        print("You have used ", lives_used, "life/lives")
                                        
                                    elif chances == 2 and correct_guess == False:
                                        print('''
                                              +---+
                                              |   |
                                              O   |
                                              |   |
                                                  |
                                                  |
                                            =========''')
                                        lives_left -= 1
                                        lives_used += 1
                                        print()
                                        print("You are now left with ", lives_left, "chances")
                                        print("You have used ", lives_used, "life/lives")
                                        
                                    elif chances == 3 and correct_guess == False:
                                        print('''
                                              +---+
                                              |   |
                                              O   |
                                             /|   |
                                                  |
                                                  |
                                            =========''')
                                        lives_left -= 1
                                        lives_used += 1
                                        print()
                                        print("You are now left with ", lives_left, "chances")
                                        print("You have used ", lives_used, "life/lives")
                                        
                                    elif chances == 4 and correct_guess == False:
                                        print('''
                                              +---+
                                              |   |
                                              O   |
                                             /|\  |
                                                  |
                                                  |
                                            =========''')  
                                        lives_left -= 1
                                        lives_used += 1
                                        print()
                                        print("You are now left with ", lives_left, "chances")
                                        print("You have used ", lives_used, "life/lives")
                                        
                                    elif chances == 5 and correct_guess == False:
                                        print('''
                                              +---+
                                              |   |
                                              O   |
                                             /|\  |
                                             /    |
                                                  |
                                            =========''')
                                        lives_left -= 1
                                        lives_used += 1
                                        print()
                                        print("You are now left with ", lives_left, "chances")
                                        print("You have used ", lives_used, "life/lives")
                                        
                                    elif chances == 6 and correct_guess == False:
                                        print('''
                                              +---+
                                              |   |
                                              O   |
                                             /|\  |
                                             / \  |
                                                  |
                                            =========''')
                                        print()
                                        print("The correct word is", word)
                                        print()
                                        print("Game Over")
                                        chances = 8
                                        break
                                        
                                    count = 0         
                                    for letter in range(0, len(dummy_word)):
                                        if dummy_word[letter] == word[letter]:
                                            count += 1
                                    if count == len(word):
                                        print()
                                        print("Congratulations! you have correctly guessed the word ")
                                        chances = 7
                                        break
                
                        except ValueError:
                            print("Invalid data type. Please enter a character")
                            print()
            
            elif level == "hard": 
                category_check = False
                lives_left = 3
                lives_used = 0

                while category_check == False: 
                    try: 
                        category = input("Choose a category (countries/colours/fruits): ")
                        if (((category.strip()).lower() != "countries") and ((category.strip()).lower() != "colors") and ((category.strip()).lower() != "colours") and ((category.strip()).lower() != "fruits")):
                            print("Please choose a category(countries/colours/fruits)")
                        elif category.strip() == "":
                            print("Please choose a category(countries/colours/fruits)")
                        else:
                            category_check = True
                            
                    except ValueError:
                        print("Invalid data type. Please enter a string for the category")

                    rand_no = random.randint(0,24)
                    word = ""

                    if category.lower() == "countries":
                        word = countries[rand_no].lower()
                    elif (category.lower()== "colors") or (category.lower() == "colours"):
                        word = colours[rand_no].lower()
                    elif category.lower() == "fruits":
                        word = fruits[rand_no].lower()
                    
                    guesses = []
                    for i in word:
                        if (i in "aeiou") and (i not in guesses):
                            guesses.append(i)

                    dummy_word = []
                    for i in range(0, len(word)):
                        dummy_word.append("")
                        
                    for i in range(0, len(word)):
                        if word[i] in "aeiou":
                            dummy_word[i] = word[i]
                        elif word[i] == " ":
                            dummy_word[i] = " "
                        else:
                           dummy_word[i] = " _ "

                    for p in range(0, len(word)):
                        print(dummy_word[p], end = "")
                    
                    print()
                    chances = 0
 
                    while chances < 3:
                        answer_check = False
                        while answer_check == False:
                            try: 
                                answer = input("Guess a letter !")
                                print()
                                if len(answer.strip()) > 1:
                                    print("Please enter a single letter ")
                                    print()
                                elif len(answer.strip()) == 1:
                                    guess_check = False
                                    for guess in guesses: 
                                        if guess == answer:
                                            guess_check = True
                                            break
                                    if guess_check == True: 
                                        print("This letter is already there and/or guessed, Please try another letter !")
                                            
                                    else:
                                        correct_guess = False
                                        answer_check = True
                                        guesses.append(answer)
                                        if answer in word:
                                            for i in range(0, len(word)):
                                                if answer == word[i]:
                                                    dummy_word[i] = word[i]
                                                    correct_guess = True
                                                    
                                            if correct_guess == True: 
                                                print("It is a correct guess !!")
                        
                                            for p in range(0, len(word)):
                                                print(dummy_word[p], end = "")
              
                                        else: 
                                            print("Sorry ! It is a wrong guess. Try again")
                                        
                                            chances += 1
                                        
                                            for p in range(0, len(word)):
                                                print(dummy_word[p], end = "")
                                            
                                        if chances == 1 and correct_guess == False:
                                            print('''
                                                  +---+
                                                  |   |
                                                  O   |
                                                  |   |
                                                      |
                                                      |
                                                =========''')
                                            lives_left -= 1
                                            lives_used += 1
                                            print()
                                            print("You are now left with ", lives_left, "chances")
                                            print("You have used ", lives_used, "life/lives")
                                            
                                        elif chances == 2 and correct_guess == False:
                                            print('''
                                                  +---+
                                                  |   |
                                                  O   |
                                                 /|\  |
                                                      |
                                                      |
                                                =========''')  
                                            lives_left -= 1
                                            lives_used += 1
                                            print()
                                            print("You are now left with ", lives_left, "chances")
                                            print("You have used ", lives_used, "life/lives")
                                            
                                        elif chances == 3 and correct_guess == False:
                                            print('''
                                                  +---+
                                                  |   |
                                                  O   |
                                                 /|\  |
                                                 / \  |
                                                      |
                                                =========''')
                                            print()
                                            print("The correct word is", word)
                                            print()
                                            print("Game Over")
                                            chances = 5
                                            break
                                            
                                        count = 0         
                                        for letter in range(0, len(dummy_word)):
                                            if dummy_word[letter] == word[letter]:
                                                count += 1
                                                
                                        if count == len(word):
                                            print()
                                            print("Congratulations! you have correctly guessed the word ")
                                            chances = 4
                                            break
                                        
                            except ValueError:
                                print("Invalid data type. Please enter a character")
        print()
    except ValueError:
        print("Please enter a string value")

    choice = input("Do you wish to play again ?(yes/no)")
    if choice.strip().lower() not in "yesno":
        print("Please enter a valid choice.Do you wish to play again ?(yes/no)")
    else: 
        if choice in "no":
            continue_game = False
            print()
        else:
             continue_game = True
             print()
